# %%
import numpy as np
import pandas as pd
import parselmouth
from parselmouth.praat import call
import librosa
import librosa.display
import matplotlib.pyplot as plt
import os
import glob
from tqdm import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
DATA_DIR = "H:\Voice Pathlogy Detection\Dataset\Saarbrucken_converted"
HEALTHY_DIR = os.path.join(DATA_DIR, "healthy")
PATHOLOGICAL_DIR = os.path.join(DATA_DIR, "pathological")

print(f"Data directories:")
print(f"  Healthy: {HEALTHY_DIR}")
print(f"  Pathological: {PATHOLOGICAL_DIR}")
# Out:
# Data directories:
#   Healthy: H:\Voice Pathlogy Detection\Dataset\Saarbrucken_converted\healthy
#   Pathological: H:\Voice Pathlogy Detection\Dataset\Saarbrucken_converted\pathological

# %%
def extract_mfcc_features(file_path, n_mfcc=13):
    try:
        #Load recording
        y, sr = librosa.load(file_path, sr=None) #sr is set to None to prevent downsampling to 22.05 kHz
        print(sr)
        #Extract MFCCs
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
        delta_mfccs = librosa.feature.delta(mfccs)
        delta2_mfccs = librosa.feature.delta(mfccs, order=2)

        #Calculate mean and std
        mfcc_mean = np.mean(mfccs, axis=1)
        mfcc_std = np.std(mfccs, axis=1)
        delta_mean = np.mean(delta_mfccs, axis=1)
        delta_std = np.std(delta_mfccs, axis=1)
        delta2_mean = np.mean(delta2_mfccs, axis=1)
        delta2_std = np.std(delta2_mfccs, axis=1)
        
        return np.concatenate([mfcc_mean, mfcc_std, delta_mean, delta_std, delta2_mean, delta2_std])
    
    except Exception as e:
        print(f"Error: {file_path}: {e}")
        return None

# %%
def extract_other_features(file_path):
    try:
        sound = parselmouth.Sound(file_path)
        pitch = call(sound, "To Pitch", 0.0, 75, 600)
        point_process = call(sound, "To PointProcess (periodic, cc)", 75, 600)
        
        # Jitter
        jitter_local = call(point_process, "Get jitter (local)", 0, 0, 0.0001, 0.02, 1.3)
        jitter_rap = call(point_process, "Get jitter (rap)", 0, 0, 0.0001, 0.02, 1.3)
        
        # Shimmer
        shimmer_local = call([sound, point_process], "Get shimmer (local)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
        shimmer_apq3 = call([sound, point_process], "Get shimmer (apq3)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
        
        # HNR
        harmonicity = call(sound, "To Harmonicity (cc)", 0.01, 75, 0.1, 1.0)
        hnr = call(harmonicity, "Get mean", 0, 0)
        
        return [jitter_local, jitter_rap, shimmer_local, shimmer_apq3, hnr]
    
    except Exception as e:
        print(f"Error: {file_path}: {e}")
        return None

# %%
mfcc_names = (
    [f"mfcc_{i}_mean" for i in range(1, 14)] +
    [f"mfcc_{i}_std" for i in range(1, 14)] +
    [f"d_mfcc_{i}_mean" for i in range(1, 14)] +
    [f"d_mfcc_{i}_std" for i in range(1, 14)] +
    [f"d2_mfcc_{i}_mean" for i in range(1, 14)] +
    [f"d2_mfcc_{i}_std" for i in range(1, 14)]
)
other_names = ["jitter_local", "jitter_rap", "shimmer_local", "shimmer_apq3", "hnr"]
feature_names = mfcc_names + other_names

# %%
def extract_all_features(file_path):
    mfcc = extract_mfcc_features(file_path)
    other = extract_other_features(file_path)
    
    return np.concatenate([mfcc, other])

# %% [markdown]
# ## Loop

# %%
def extract_healthy():
    features = []
    patterns = ['a_h', 'a_n', 'a_l', 'a_lhl', 'i_h', 'i_n', 'i_l', 'i_lhl', 'u_h', 'u_n', 'u_l', 'u_lhl', 'iau']
    for person_id in os.listdir(HEALTHY_DIR):
        person_path = os.path.join(HEALTHY_DIR, person_id)

        #Sentence
        sentence_path = os.path.join(person_path, f"sentences\\{person_id}-phrase.wav")
        features.append((sentence_path, 0, 'healthy', person_id, 'sentence'))

        #Vowels
        for pattern in patterns:
            vowel_path = os.path.join(person_path, f"vowels\\{person_id}-{pattern}.wav")
            if os.path.exists(vowel_path):
                features.append((vowel_path, 0, 'healthy', person_id, pattern))
                
    return features

# %%
data = extract_healthy()
print(data)
# Out:
# [('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\sentences\\1-phrase.wav', 0, 'healthy', '1', 'sentence'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-a_h.wav', 0, 'healthy', '1', 'a_h'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-a_n.wav', 0, 'healthy', '1', 'a_n'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-a_l.wav', 0, 'healthy', '1', 'a_l'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-a_lhl.wav', 0, 'healthy', '1', 'a_lhl'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-i_h.wav', 0, 'healthy', '1', 'i_h'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-i_n.wav', 0, 'healthy', '1', 'i_n'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-i_l.wav', 0, 'healthy', '1', 'i_l'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-i_lhl.wav', 0, 'healthy', '1', 'i_lhl'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-u_h.wav', 0, 'healthy', '1', 'u_h'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-u_n.wav', 0, 'healthy', '1', 'u_n'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-u_l.wav', 0, 'healthy', '1', 'u_l'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-u_lhl.wav', 0, 'healthy', '1', 'u_lhl'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\1\\vowels\\1-iau.wav', 0, 'healthy', '1', 'iau'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\sentences\\10-phrase.wav', 0, 'healthy', '10', 'sentence'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-a_h.wav', 0, 'healthy', '10', 'a_h'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-a_n.wav', 0, 'healthy', '10', 'a_n'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-a_l.wav', 0, 'healthy', '10', 'a_l'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-a_lhl.wav', 0, 'healthy', '10', 'a_lhl'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-i_h.wav', 0, 'healthy', '10', 'i_h'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-i_n.wav', 0, 'healthy', '10', 'i_n'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-i_l.wav', 0, 'healthy', '10', 'i_l'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-i_lhl.wav', 0, 'healthy', '10', 'i_lhl'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-u_h.wav', 0, 'healthy', '10', 'u_h'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-u_n.wav', 0, 'healthy', '10', 'u_n'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-u_l.wav', 0, 'healthy', '10', 'u_l'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-u_lhl.wav', 0, 'healthy', '10', 'u_lhl'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\10\\vowels\\10-iau.wav', 0, 'healthy', '10', 'iau'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\100\\sentences\\100-phrase.wav', 0, 'healthy', '100', 'sentence'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\100\\vowels\\100-a_h.wav', 0, 'healthy', '100', 'a_h'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healthy\\100\\vowels\\100-a_n.wav', 0, 'healthy', '100', 'a_n'), ('H:\\Voice Pathlogy Detection\\Dataset\\Saarbrucken_converted\\healt ...
